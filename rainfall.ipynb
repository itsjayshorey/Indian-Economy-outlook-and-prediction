# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
rainfall_data=pd.read_excel("rainfall.xlsx")

# %%
print(rainfall_data.columns)
x_cord=rainfall_data['Precipitation\xa0(cm)']
print(rainfall_data)
# Out:
# Index(['Year', 'Rank', 'Precipitation (cm)'], dtype='object')
#      Year  Rank  Precipitation (cm)
# 0    2021    20               121.6
# 1    2020    14               124.6
# 2    2019     3               132.6
# 3    2018   105               102.4
# 4    2017    45               116.1
# ..    ...   ...                 ...
# 116  1905   117                95.9
# 117  1904   115                97.6
# 118  1903    33               118.7
# 119  1902    85               107.0
# 120  1901   110               100.4
#
# [121 rows x 3 columns]

# %%
print(rainfall_data['Year'])

rainfall_data=rainfall_data[rainfall_data['Year']>1960]
# Out:
# 0      2021
# 1      2020
# 2      2019
# 3      2018
# 4      2017
#        ...
# 116    1905
# 117    1904
# 118    1903
# 119    1902
# 120    1901
# Name: Year, Length: 121, dtype: int64

# %%
plt.plot(rainfall_data['Year'],rainfall_data['Precipitation\xa0(cm)'])

# %%
avg=0
for el in rainfall_data["Precipitation\xa0(cm)"]:
    avg+=el
avg=avg/(2024-1960)
print(avg)
his=[]
for el in rainfall_data["Precipitation\xa0(cm)"]:
    his.append(el-avg)
plt.figure(figsize=(8, 16))
plt.bar(rainfall_data['Year'],hist)
plt.axhline(y=0, color='r', linestyle='--', label='Zero Line')
# Out:
# 106.8859375

# %% [markdown]
# ![image.png](attachment:image.png)
